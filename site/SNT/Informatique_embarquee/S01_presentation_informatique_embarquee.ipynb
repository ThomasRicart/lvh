# %% [markdown]
# # 🤖 Informatique Embarquée et Objets Connectés
# ## Séance 1 — Présentation générale
# **SNT — Seconde** | Durée : ~1 heure
#
# ---

# %% [markdown]
# ## 🎯 Objectifs de la séance
#
# À la fin de cette séance, vous serez capable de :
# - Expliquer ce qu'est un **système informatique embarqué**
# - Distinguer **capteurs**, **actionneurs** et **IHM**
# - Donner des exemples d'objets connectés du quotidien
# - Identifier les enjeux de sécurité liés à ces objets

# %% [markdown]
# ---
# ## 📌 Partie 1 — Qu'est-ce que l'informatique embarquée ?
#
# Un **système informatique embarqué** est un système informatique intégré directement dans un objet pour contrôler son fonctionnement.
#
# Contrairement à un ordinateur classique, il est :
# - **dédié** à une tâche précise
# - **miniaturisé** (souvent un microprocesseur peu coûteux)
# - souvent soumis à des **contraintes de temps réel** (il doit répondre rapidement)
#
# ![image.png](attachment:image.png)
#
# ### 🕰️ Quelques repères historiques
#
# | Année | Événement |
# |-------|-----------|
# | 1967  | 1er système embarqué : guidage de la mission lunaire Apollo |
# | 1971  | 1er microprocesseur (Intel) |
# | 1984  | Airbus A320 : 1er avion à commandes électriques informatisées |
# | 1998  | Météor (ligne 14 Paris) : 1er métro sans conducteur |
# | 1999  | Naissance de l'expression « Internet des objets » |
# | 2007  | Arrivée du smartphone |
# | 2020  | ~50 milliards d'objets connectés dans le monde |

# %% [markdown]
# ### ✏️ Question 1
# Citez **3 objets** de votre quotidien qui contiennent un système informatique embarqué. Pour chacun, précisez **à quoi sert** l'informatique dans cet objet.

# %% [markdown]
# **Votre réponse ici :**
#
# 1. ...
# 2. ...
# 3. ...

# %% [markdown]
# ---
# ## 📌 Partie 2 — Les composants d'un système embarqué
#
# Un système embarqué interagit avec le monde physique grâce à 3 types de composants :
#
# ![image.png](attachment:image.png)
#
#
#
# ### 🔍 Les capteurs
# Un **capteur** mesure une grandeur physique et la convertit en signal numérique.
#
# Exemples : thermomètre, accéléromètre, caméra, microphone, capteur de luminosité, GPS...
#
# ### ⚙️ Les actionneurs
# Un **actionneur** reçoit un signal numérique et produit une action physique.
#
# Exemples : moteur, LED, haut-parleur, écran, pompe, résistance chauffante...
#
# ### 🖥️ L'IHM (Interface Homme-Machine)
# L'**IHM** permet à un humain d'interagir avec le système.
#
# Exemples : boutons, écran tactile, application smartphone, télécommande...

# %% [markdown]
# ### ✏️ Question 2 — Le thermostat connecté
#
# Un thermostat connecté (comme le Nest: https://conseils-thermiques.org/contenu/test-thermostat-nest.php) permet de réguler la température d'une maison depuis un smartphone.
#
# Complétez le tableau suivant en identifiant les capteurs, actionneurs et IHM de ce système :
#
# | Composant | Nom | Rôle |
# |-----------|-----|------|
# | Capteur   | ... | ... |
# | Actionneur | ... | ... |
# | IHM       | ... | ... |

# %% [markdown]
# ### ✏️ Question 3 — La voiture autonome
#
# La voiture autonome utilise de nombreux capteurs : caméras, radars, lidars (lasers), GPS...
#
# 1. À quoi sert chacun de ces capteurs ? Faites une petite recherche si nécessaire.
# 2. Quels actionneurs la voiture utilise-t-elle pour se déplacer ?
# 3. Quelle est l'IHM pour le conducteur ?

# %% [markdown]
# **Votre réponse ici :**
#
# ...

# %% [markdown]
# ---
# ## 📌 Partie 3 — Les objets connectés et l'Internet des Objets (IoT)
#
# Un objet **connecté** est un objet embarqué qui communique via un réseau (souvent Internet ou Bluetooth ou Wi-Fi).
#
# L'ensemble de ces objets forme l'**Internet des Objets** (*Internet of Things*, IoT).
#
# Grâce au smartphone, on peut désormais contrôler de nombreux objets depuis une seule interface unifiée.
#
# ### 🌍 Exemples d'applications
# - **Domotique** : éclairage, chauffage, alarme, électroménager
# - **Santé** : montres connectées, tensiomètres, glucomètres
# - **Transport** : voiture connectée, trottinette partagée
# - **Agriculture** : capteurs d'humidité des sols, drones
# - **Industrie** : robots de chaîne de montage

# %% [markdown]
# ### ✏️ Question 4 — Avantages et inconvénients
#
# Complétez le tableau suivant en réfléchissant aux avantages et inconvénients des objets connectés :
#
# | Avantages | Inconvénients / Risques |
# |-----------|-------------------------|
# | ...       | ...                     |
# | ...       | ...                     |
# | ...       | ...                     |

# %% [markdown]
# ---
# ## 📌 Partie 4 — Sécurité et sûreté
#
# L'informatique embarquée pose deux problèmes majeurs :
#
# - 🛡️ **La sûreté** (*safety*) : s'assurer que le système fonctionne **sans erreur** (un bug dans un avion peut être fatal)
# - 🔒 **La sécurité** (*security*) : résister aux **attaques informatiques**
#
# > Des objets connectés mal sécurisés peuvent être utilisés comme **robots** pour lancer des attaques sur Internet (on parle de *botnet*).
#
# ### ✏️ Question 5
#
# En 2016, une attaque informatique massive (Mirai) a utilisé des milliers de caméras de surveillance et routeurs connectés pour bloquer des sites comme Twitter ou Netflix.
#
# 1. Pourquoi ces objets ont-ils pu être piratés facilement selon vous ?
# 2. Que peuvent faire les fabricants pour éviter cela ?
# 3. Que peuvent faire les utilisateurs ?

# %% [markdown]
# **Votre réponse ici :**
#
# ...

# %% [markdown]
# ---
# ## 🏁 Synthèse — À retenir
#
# Complétez cette synthèse avec vos propres mots :
#
# - Un système informatique embarqué est ...
# - Un **capteur** permet de ...
# - Un **actionneur** permet de ...
# - Une **IHM** permet de ...
# - Un objet **connecté** est un objet embarqué qui ...
# - Les principaux risques liés aux objets connectés sont ...
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ---
# ## 🔎 Pour aller plus loin (facultatif)
#
# - Regardez la vidéo « C'est pas sorcier — Les robots » sur YouTube
# - Recherchez : *Comment fonctionne un lidar sur une voiture autonome ?*
# - Que signifie « temps réel » en informatique ? Cherchez un exemple concret.

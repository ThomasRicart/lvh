# %% [markdown]
# # 🕹️ Réaliser une Interface Homme-Machine (IHM)
# ## Séance 2 — Activité guidée avec Tinkercad + carte micro:bit
# **SNT — Seconde** | Durée : ~2 heures
#
# ---
# > **Outil utilisé :** [Tinkercad Circuits](https://www.tinkercad.com) — simulation en ligne, **aucune installation nécessaire**.
# >
# > 🔑 Créez un compte gratuit sur tinkercad.com avant de commencer.

# %% [markdown]
# ## 🎯 Objectifs
#
# - Comprendre ce qu'est une IHM dans un objet embarqué
# - Programmer une carte micro:bit pour réagir à des entrées (boutons, capteurs)
# - Contrôler des sorties (LEDs, affichage, buzzer)
# - Simuler un petit système embarqué complet

# %% [markdown]
# ---
# ## 📌 La carte micro:bit
#
# La carte **BBC micro:bit** est une carte microcontrôleur conçue pour l'éducation. Elle possède :
#
# | Composant | Rôle |
# |-----------|------|
# | Matrice 5×5 LEDs | Afficher du texte, des images |
# | Boutons A et B | Entrées utilisateur (IHM) |
# | Accéléromètre | Détecter les mouvements, la secousse |
# | Capteur de température | Mesurer la température |
# | Boussole | Orientation magnétique |
# | Bluetooth / Radio | Communiquer avec d'autres appareils |
#
# Dans Tinkercad, on peut la programmer en **Python (MicroPython)** ou en blocs visuels.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
# ## 🏗️ ACTIVITÉ 1 — Prise en main (20 min)
#
# ### Étape 1 — Créer un nouveau projet
#
# 1. Connectez-vous à [tinkercad.com](https://www.tinkercad.com)
# 2. Cliquez sur **Circuits** → **Créer un nouveau circuit**
# 3. Dans la bibliothèque à droite, cherchez **micro:bit** et glissez-le sur la zone de travail
# 4. Cliquez sur **Code** en haut → choisissez le mode **Python**
#
# ### Étape 2 — Premier programme : afficher un message
#
# Copiez ce code dans l'éditeur Tinkercad :
#
# ```python
# from microbit import *
#
# # Afficher un message défilant
# display.scroll("Bonjour !")
#
# # Afficher une image (cœur)
# display.show(Image.HEART)
# sleep(2000)
#
# # Éteindre l'écran
# display.clear()
# ```
#
# 5. Cliquez sur **Démarrer la simulation** ▶️
# 6. Observez la matrice de LEDs sur la carte.

# %% [markdown]
# ### ✏️ Question 1
#
# 1. Que fait la fonction `display.scroll()` ?
# 2. Que fait `sleep(2000)` ? (indice : l'unité est la milliseconde)
# 3. Cherchez dans la documentation MicroPython micro:bit d'autres images disponibles (ex : `Image.HAPPY`, `Image.SAD`...) et testez-en deux.

# %% [markdown]
# **Votre réponse ici :**
#
# ...

# %% [markdown]
# ---
# ## 🏗️ ACTIVITÉ 2 — Les boutons comme IHM (30 min)
#
# Les boutons **A** et **B** sont nos entrées utilisateur : c'est l'**Interface Homme-Machine**.
#
# ### Le code de base avec les boutons
#
# ```python
# from microbit import *
#
# while True:
#     if button_a.is_pressed():
#         display.show(Image.HAPPY)
#     elif button_b.is_pressed():
#         display.show(Image.SAD)
#     else:
#         display.show(Image.ASLEEP)
#     sleep(100)
# ```
#
# ### ✏️ Question 2 — Analyse du code
#
# 1. Pourquoi utilise-t-on une boucle `while True` ?
# 2. Que se passe-t-il si on appuie sur aucun bouton ?
# 3. Que se passe-t-il si on appuie sur les deux boutons en même temps ? Testez et expliquez.
# 4. Quelle est l'**IHM** dans ce système ? Quel est l'**actionneur** ?

# %% [markdown]
# **Votre réponse ici :**
#
# ...

# %% [markdown]
# ### 🎮 Mini-défi : Le compteur de points
#
# Modifiez le programme pour qu'il fonctionne comme un **compteur** :
# - Le bouton **A** incrémente le compteur (+1)
# - Le bouton **B** remet le compteur à 0
# - La valeur actuelle est **affichée** sur la matrice LED
#
# **Aide :** Vous aurez besoin d'une variable `compteur = 0` et de `display.show(compteur)`.
#
# ⚠️ Attention à la méthode `was_pressed()` plutôt que `is_pressed()` pour ne compter qu'un appui à la fois !

# %% [markdown]
# **Collez votre code ici :**
#
# ```python
# # Votre code ici
#
#
#
# ```

# %% [markdown]
# ---
# ## 🏗️ ACTIVITÉ 3 — Le thermomètre connecté (40 min)
#
# On va maintenant utiliser un **capteur** (thermomètre intégré) et créer une IHM complète.
#
# ### Objectif : Station météo mini
#
# Le système doit :
# 1. Lire la **température** en continu
# 2. Afficher un **emoji** selon la température :
#    - ❄️ Si T < 18°C → `Image.SURPRISED` (froid)
#    - 😊 Si 18 ≤ T ≤ 25°C → `Image.HAPPY` (confortable)
#    - 🔥 Si T > 25°C → `Image.ANGRY` (chaud)
# 3. Quand on appuie sur **A** → afficher la valeur numérique de la température
# 4. Quand on appuie sur **B** → afficher la valeur en Fahrenheit (F = T × 9/5 + 32)
#
# ### Code de départ
#
# ```python
# from microbit import *
#
# while True:
#     temperature = temperature()  # Lecture du capteur
#
#     if button_a.was_pressed():
#         # Afficher la température en Celsius
#         display.scroll(str(temperature) + "C")
#
#     elif button_b.was_pressed():
#         # À COMPLÉTER : afficher en Fahrenheit
#         pass
#
#     else:
#         # Afficher l'emoji selon la température
#         if temperature < 18:
#             # À COMPLÉTER
#             pass
#         elif temperature <= 25:
#             # À COMPLÉTER
#             pass
#         else:
#             # À COMPLÉTER
#             pass
#
#     sleep(500)
# ```
#
# > **Note Tinkercad** : Dans la simulation, vous pouvez régler manuellement la température du capteur en cliquant sur le composant température de la carte.

# %% [markdown]
# ### ✏️ Question 3 — Complétez le code
#
# Recopiez le code complété ci-dessous :

# %% [markdown]
# ```python
# # Votre code complété ici
#
#
#
# ```

# %% [markdown]
# ### ✏️ Question 4 — Analyse du système
#
# Remplissez le tableau qui décrit votre système embarqué :
#
# | Composant | Nom | Rôle dans le système |
# |-----------|-----|----------------------|
# | Capteur   | ... | ... |
# | IHM entrée | ... | ... |
# | IHM sortie | ... | ... |
# | Actionneur | ... | ... |

# %% [markdown]
# ---
# ## 🏗️ ACTIVITÉ 4 — Bonus : L'accéléromètre (si temps disponible)
#
# La micro:bit possède aussi un **accéléromètre** qui détecte les mouvements. On peut détecter une **secousse** (shake) !
#
# ```python
# from microbit import *
# import random
#
# # Simulateur de dé à 6 faces
# display.show(Image.DIAMOND)
#
# while True:
#     if accelerometer.was_gesture('shake'):
#         # Générer un nombre aléatoire entre 1 et 6
#         valeur = random.randint(1, 6)
#         display.show(str(valeur))
#         sleep(1000)
#         display.show(Image.DIAMOND)
#     sleep(100)
# ```
#
# Dans Tinkercad, vous pouvez simuler une secousse en cliquant sur le bouton **Shake** qui apparaît dans la simulation.
#
# ### 🎮 Défi bonus
#
# Modifiez le dé pour qu'il :
# - Affiche **différentes images** selon le chiffre (1 point, 2 points... comme un vrai dé)
# - Garde en mémoire le **nombre de 6 obtenus** et l'affiche quand on appuie sur A

# %% [markdown]
# ---
# ## 🏁 Bilan de séance
#
# ### ✏️ Question finale
#
# 1. Qu'est-ce qu'une IHM ? Donnez sa définition avec vos propres mots.
# 2. Citez deux **entrées** et deux **sorties** de la micro:bit que vous avez utilisées.
# 3. Pourquoi utilise-t-on une boucle `while True` dans les programmes embarqués ?
# 4. Qu'est-ce que le **temps réel** dans un système embarqué ? La micro:bit répond-elle en temps réel ?

# %% [markdown]
# **Votre réponse :**
#
# ...

# %% [markdown]
# ---
# ## 📚 Résumé — Ce que vous avez appris
#
# | Concept | Ce que vous savez faire |
# |---------|-------------------------|
# | IHM | Utiliser boutons (entrée) et LEDs (sortie) |
# | Capteur | Lire la température avec `temperature()` |
# | Actionneur | Contrôler l'affichage avec `display.show()` |
# | Boucle infinie | `while True` pour un fonctionnement continu |
# | Condition | `if/elif/else` pour réagir aux événements |
#
# ➡️ **La prochaine séance**, vous allez concevoir votre propre IHM !

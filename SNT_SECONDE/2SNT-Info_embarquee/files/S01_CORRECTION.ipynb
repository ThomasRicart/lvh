# %% [markdown]
# # 🤖 Informatique Embarquée et Objets Connectés
# ## Séance 1 — CORRECTION
# **SNT — Seconde** | Document professeur
#
# ---
# > 🔴 **Document réservé au professeur** — Ne pas distribuer aux élèves avant la séance.

# %% [markdown]
# ---
# ## ✅ CORRECTION — Question 1
# > *Citez 3 objets de votre quotidien qui contiennent un système informatique embarqué. Pour chacun, précisez à quoi sert l'informatique dans cet objet.*
#
# **Réponses attendues (exemples parmi d'autres) :**
#
# 1. **Le smartphone** → gère les appels, l'affichage, le Wi-Fi, les capteurs (GPS, gyroscope, caméra), les applications...
# 2. **Le lave-linge** → gère le programme de lavage, la température de l'eau, la durée du cycle, la vitesse d'essorage
# 3. **La voiture** → gère l'ABS (freinage), l'injection du moteur, l'airbag, la navigation GPS, le régulateur de vitesse
#
# **Autres réponses valides :** four à micro-ondes, réfrigérateur connecté, montre connectée, console de jeux, box internet, téléviseur, distributeur automatique, ascenseur, feux de circulation...
#
# **Points à valoriser :**
# - La précision du rôle de l'informatique (pas juste « il calcule »)
# - La diversité des domaines cités
# - Des objets auxquels on ne pense pas spontanément (feux tricolores, machine à café...)

# %% [markdown]
# ---
# ## ✅ CORRECTION — Question 2 — Le thermostat connecté
# > *Identifiez les capteurs, actionneurs et IHM du thermostat Nest.*
#
# | Composant | Nom | Rôle |
# |-----------|-----|------|
# | **Capteur** | Sonde de température | Mesure la température ambiante de la pièce |
# | **Capteur** (bonus) | Capteur de présence (infrarouge) | Détecte si quelqu'un est dans la pièce pour adapter le chauffage |
# | **Actionneur** | Chaudière / système de chauffage | Produit de la chaleur en réponse aux ordres du thermostat |
# | **IHM (entrée)** | Bouton rotatif sur le Nest / Application smartphone | L'utilisateur règle la température souhaitée |
# | **IHM (sortie)** | Écran circulaire du Nest / Application smartphone | Affiche la température actuelle et la consigne |
#
# **Remarque pédagogique :** L'application smartphone est à la fois IHM entrée (l'utilisateur programme) et IHM sortie (l'utilisateur consulte). C'est un bon exemple de composant à double rôle.

# %% [markdown]
# ---
# ## ✅ CORRECTION — Question 3 — La voiture autonome
# > *Capteurs, actionneurs et IHM de la voiture autonome.*
#
# **1. Rôle des capteurs :**
#
# | Capteur | Rôle |
# |---------|------|
# | **Caméra** | Reconnaît les panneaux, les marquages au sol, les piétons, les feux de signalisation |
# | **Radar** | Mesure la distance et la vitesse des obstacles (fonctionne par tous temps, même brouillard/pluie) |
# | **Lidar** (laser) | Cartographie l'environnement en 3D avec une grande précision (nuage de points) |
# | **GPS** | Localise la voiture et planifie le trajet |
# | **Accéléromètre / gyroscope** | Mesure les mouvements et l'équilibre du véhicule |
#
# **2. Actionneurs :**
# - Moteur électrique / injection (propulsion)
# - Freins (système de freinage)
# - Direction (volant motorisé)
# - Clignotants, feux
# - Klaxon
#
# **3. IHM pour le conducteur :**
# - Écran tactile central (destination, paramètres de conduite autonome)
# - Tableau de bord (vitesse, alertes)
# - Volant et pédales (reprise manuelle possible)
# - Alertes sonores et visuelles
#
# **Note pédagogique :** C'est l'occasion de discuter du niveau d'autonomie (niveaux 0 à 5 SAE). En 2024, la plupart des voitures commerciales sont au niveau 2-3.

# %% [markdown]
# ---
# ## ✅ CORRECTION — Question 4 — Avantages et inconvénients des objets connectés
#
# | Avantages | Inconvénients / Risques |
# |-----------|-------------------------|
# | Confort et praticité (contrôle à distance) | Risque de piratage / vol de données personnelles |
# | Économies d'énergie (chauffage intelligent) | Dépendance à Internet et aux serveurs (si le serveur tombe, l'objet ne fonctionne plus) |
# | Sécurité améliorée (alarmes, détecteurs) | Obsolescence rapide, difficile à réparer |
# | Automatisation de tâches répétitives | Consommation électrique supplémentaire |
# | Suivi médical à distance | Collecte massive de données sur nos habitudes (vie privée) |
# | Gain de temps | Coût d'achat et d'abonnement élevé |
#
# **Discussion à lancer :** *Avez-vous déjà eu un problème avec un objet connecté ? Votre enceinte connectée vous écoute-t-elle en permanence ?*

# %% [markdown]
# ---
# ## ✅ CORRECTION — Question 5 — L'attaque Mirai
# > *En 2016, des caméras et routeurs connectés ont été utilisés pour bloquer Twitter et Netflix.*
#
# **1. Pourquoi ces objets ont-ils pu être piratés facilement ?**
#
# - Ils utilisaient des **mots de passe par défaut** (souvent "admin/admin" ou "admin/1234") que les utilisateurs n'avaient jamais changés
# - Les fabricants n'avaient pas prévu de système de mise à jour automatique
# - La sécurité n'était pas une priorité lors de leur conception (objets bon marché)
# - Beaucoup d'utilisateurs ne savent pas que leur caméra ou routeur peut être piraté
#
# **2. Ce que peuvent faire les fabricants :**
# - Forcer le changement du mot de passe lors de la première utilisation
# - Proposer des mises à jour automatiques de sécurité
# - Chiffrer les communications
# - Faire certifier leurs produits par des organismes de sécurité
#
# **3. Ce que peuvent faire les utilisateurs :**
# - Changer le mot de passe par défaut dès l'installation
# - Mettre à jour régulièrement le firmware (logiciel interne) de leurs appareils
# - Ne pas connecter des appareils inutilement
# - Utiliser un réseau Wi-Fi séparé pour les objets connectés
#
# **Note pédagogique :** L'attaque Mirai a généré un trafic de **1,2 Tbps**, record mondial à l'époque. C'est un excellent exemple pour illustrer que la sécurité est l'affaire de tous.

# %% [markdown]
# ---
# ## ✅ CORRECTION — Synthèse
# > *Complétez la synthèse avec vos propres mots.*
#
# - Un **système informatique embarqué** est un système informatique intégré dans un objet, dédié à une tâche précise, souvent miniaturisé et soumis à des contraintes de temps réel.
#
# - Un **capteur** permet de mesurer une grandeur physique (température, lumière, pression...) et de la convertir en signal numérique exploitable par le microprocesseur.
#
# - Un **actionneur** permet de convertir un signal numérique en action physique (faire tourner un moteur, allumer une LED, émettre un son...).
#
# - Une **IHM** (Interface Homme-Machine) permet à un humain d'interagir avec le système : en entrée (boutons, clavier, capteur tactile) et en sortie (écran, voyants, haut-parleur).
#
# - Un objet **connecté** est un objet embarqué qui peut communiquer avec d'autres appareils ou avec Internet via Wi-Fi, Bluetooth ou d'autres protocoles réseau.
#
# - Les principaux **risques** liés aux objets connectés sont : le piratage informatique, le vol de données personnelles, la panne en cas de coupure réseau, et l'utilisation des objets comme relais d'attaques (botnets).

# %% [markdown]
# ---
# ## 📝 Notes pédagogiques générales
#
# **Erreurs fréquentes des élèves :**
# - Confondre **capteur** et **actionneur** (penser que le thermomètre « chauffe » la pièce)
# - Penser que seuls les ordinateurs et smartphones contiennent des systèmes embarqués
# - Ne pas distinguer **sûreté** (safety) et **sécurité** (security) — deux mots très proches en français
#
# **Questions bonus pour les élèves rapides :**
# - Un distributeur de billets : quels sont ses capteurs, actionneurs et IHM ?
# - Est-ce que votre téléphone est un système embarqué ? Justifiez.
# - Cherchez la différence entre un microprocesseur et un microcontrôleur.
